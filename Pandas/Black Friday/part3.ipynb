# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("BlackFriday.csv")
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
del df["Product_Category_2"]
del df["Product_Category_3"]

# %%
df.groupby("Gender").size().plot(kind="pie",autopct="%.1f",figsize=(6,6))
# Out:
# <Axes: >

# %%
df.groupby("Age").size().plot(kind="pie",autopct="%.1f",figsize=(6,6))
# Out:
# <Axes: >

# %%
df.groupby("Occupation").size().plot(kind="pie",autopct="%.1f",figsize=(6,6))
# Out:
# <Axes: >

# %%
df.groupby("City_Category").size().plot(kind="pie",autopct="%.1f",figsize=(6,6))
# Out:
# <Axes: >

# %%
df.groupby("Marital_Status").size().plot(kind="pie",autopct="%.1f",figsize=(6,6))
# Out:
# <Axes: >

# %%
df.groupby("Stay_In_Current_City_Years").size().plot(kind="pie",autopct="%.1f",figsize=(6,6))
# Out:
# <Axes: >

# %%
sns.displot(df["Age"],kde=True,color="blue")

# %%
df.groupby('Age').size().plot(kind = 'bar', figsize = (6,6))
# Out:
# <Axes: xlabel='Age'>

# %%
# Out:
# 3623
